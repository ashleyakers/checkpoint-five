# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('games-Copy1.csv')

df.head()
# Out:
#    Unnamed: 0  app_id                                              title  \
# 0           0   11190             Sherlock Holmes versus Jack the Ripper
# 1           1   20700                                          Starscape
# 2           2   94202              Jamestown: Gunpowder, Treason, & Plot
# 3           3  212673  Tom Clancy's Ghost Recon Future Soldier® - Khy...
# 4           4  222520                                Champions of Regnum
#
#             rating  positive_ratio  user_reviews  price_final price_original  \
# 0  Mostly Positive              78           792         9.99           9.99
# 1    Very Positive              81            80         7.99           7.99
# 2         Positive              90            10         2.99           2.99
# 3            Mixed              60            10         9.99           9.99
# 4            Mixed              67          1098         0.00            0.0
#
#   price_discounted  discount
# 0             9.99       0.0
# ...

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
x = df['app_id']
y = df['positive_ratio']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y)
x_train
y_train
# Out:
# 1046     93
# 6962     84
# 3827     90
# 9466     86
# 226      84
#        ...
# 5162     41
# 4254     83
# 7660     83
# 5574     83
# 7706    100
# Name: positive_ratio, Length: 10101, dtype: int64

# %%
import statsmodels.api as sm
x_train_sm = sm.add_constant(x_train)
lr = sm.OLS(y_train, x_train_sm).fit()
lr.params
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         positive_ratio   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     388.6
# Date:                Sun, 05 Mar 2023   Prob (F-statistic):           6.37e-85
# Time:                        17:14:57   Log-Likelihood:                -39898.
# No. Observations:               10101   AIC:                         7.980e+04
# Df Residuals:                   10099   BIC:                         7.982e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         79.2583      0.251    315.873      0.000      78.766      79.750
# ...

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, -43440 + 0.0592*x_train, 'r')
plt.show()

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %%
y_train_pred = lr.predict(x_train_sm)

res = (y_train - y_train_pred)

fig = plt.figure()
sns.histplot(res, bins=15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.037
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It does not work in this case..
# 3. Was your plot of the error terms a bell curve? Almost, but it's pretty skewed
